# %% [markdown]
# <a href="https://colab.research.google.com/github/firdafirfirda-cyber/KKASmt1/blob/main/Fungsi_print_firda_hanifa_XI_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("halo dunia")
# Out:
# halo dunia

# %%
print("selamat datang di phython")
# Out:
# selamat datang di phython

# %%
print('firda hanifa')
# Out:
# firda hanifa

# %% [markdown]
# # Menampilkan Teks Bebas

# %% [markdown]
# # Variabel

# %%
BB = 50
print(BB)
# Out:
# 50

# %%
UMUR = 16
print(UMUR)
# Out:
# 16

# %% [markdown]
# Latihan soal
# 1. tampilkan teks bebas : Hari ini saya bahagia belajar bahasa python
# 2. tampilkan nilai variabel : mata_pelajaran_favorit = kode dan kecerdasan buatan
# 3. tampilkan nilai variabel : nilai_kka = 100
# 4. tampilkan teks bebas dan nilai variabel dengan tiga metode (f string,"+",","):" Nilai KKA saya adalah {nilai_kka} loh!"

# %% [markdown]
# jawaban latihan soal

# %%
print("hari ini saya bahagia belajar bahasa python")
# Out:
# hari ini saya bahagia belajar bahasa python

# %%
mata_pelajaran_favorit = "kode dan kecerdasan buatan"
print(mata_pelajaran_favorit)
# Out:
# kode dan kecerdasan buatan

# %%
nilai_kka = 100
print(nilai_kka)
# Out:
# 100

# %%
print(f"Nilai KKA saya adalah {nilai_kka}loh!")
# Out:
# Nilai KKA saya adalah 100loh!

# %%
print("Nilai KKA saya adalah " + str(nilai_kka) + " loh!")
# Out:
# Nilai KKA saya adalah 100 loh!

# %%
print("Nilai KKA saya adalah ", nilai_kka, "loh")

# %% [markdown]
# # Escape Character

# %%
print("Nama: firda hanifa")
print("kelas: XI.1")
print("Nomor absen: 16")
# Out:
# Nama: firda hanifa
# kelas: XI.1
# Nomor absen: 16

# %%
print("Nama: firda hanifa\nKelas: XI.1\nNomor absen: 28")
# Out:
# Nama: firda hanifa
# Kelas: XI.1
# Nomor absen: 28

# %%
print("""Nama: firda hanifa
kelas: XI.1
Nomor absen:16""")
# Out:
# Nama: firda hanifa
# kelas: XI.1
# Nomor absen:16

# %%
print("Nama\t\t: firda hanifa\nKelas\t\t: XI.1\nNomor absen\t:16")
# Out:
# Nama		: firda hanifa
# Kelas		: XI.1
# Nomor absen	:16

# %% [markdown]
# # Menampilkan Teks Bebas dan Variabel

# %%
print(f"Umur saya {UMUR} tahun")
# Out:
# Umur saya 16 tahun

# %%
nama= "firda hanifa"
print("Halo " + nama)
# Out:
# Halo firda hanifa

# %%
harga_telur=26000

print("Harga telur per 1 kg adalah ",harga_telur)
# Out:
# Harga telur per 1 kg adalah  26000

# %%
harga_telur=26000

print("Harga telur per 1 kg adalah "+ str(harga_telur))
# Out:
# Harga telur per 1 kg adalah 26000

# %%
nama_pembeli="Firda"

print("Nama pembeli telur adalah" + nama_pembeli)
# Out:
# Nama pembeli telur adalahFirda

# %% [markdown]
# #Paramater Fungsi print

# %%
nama_siswa_1="Favian"

# %%
Tahun = 2000
Bulan = "Februari"
Tanggal = 18

print(Tanggal, end=" ")
print(Bulan, end=" ")
print (Tahun)
# Out:
# 18 Februari 2000

# %%
Tahun = 2000
Bulan = "Februari"
Tanggal = 18

print(Tanggal, Bulan, Tahun, sep="/")
# Out:
# 18/Februari/2000

# %% [markdown]
# Latihan
#
# Tanggal Bulan Tahun

# %%
Tahun = 2009
Bulan = "mei"
Tanggal = 15

print(Tanggal, end=" ")
print(Bulan, end=" ")
print(Tahun)
# Out:
# 15 mei 2009

# %%
Tahun = 2009
Bulan = "mei"
Tanggal = 15

print(Tanggal, Bulan, Tahun, sep="/")
# Out:
# 15/mei/2009

# %%
Nama_depan = "Firda"
Nama_belakang = "Hanifa"

print(Nama_depan, end=" ")
print(Nama_belakang)
# Out:
# Firda Hanifa

# %%
print('Bu Shinta berkata, "Berikut adalah judul pelajaran hari senin selasa rabu silahkan disimpan di laptop masing-masing di folder local disk D:\\Jadwal Pelajaran\\Kelas XI Semester 1." ')

print("\nJadwal Pelajaran Mingguan")
print("********************************************************")
print("Jam\tSenin\t\tSelasa\t\tRabu")
print("Jam 1\tMatematika\tBahasa\t\tInformatika")
print("Jam 2\tBahasa Ing.\tSejarah\t\tMa'rifatullah")
print("Jam 3\tInformatika\tOlahraga\t")
# Out:
# Bu Shinta berkata, "Berikut adalah judul pelajaran hari senin selasa rabu silahkan disimpan di laptop masing-masing di folder local disk D:\Jadwal Pelajaran\Kelas XI Semester 1."
#
# Jadwal Pelajaran Mingguan
# ********************************************************
# Jam	Senin		Selasa		Rabu
# Jam 1	Matematika	Bahasa		Informatika
# Jam 2	Bahasa Ing.	Sejarah		Ma'rifatullah
# Jam 3	Informatika	Olahraga

# %% [markdown]
# # Tampilkan keluaran berupa:
# # Naufal-Favian-Humaira-Favian
# # Dengan paramater sep

# %%
# Tampilan keluaran berupa:
# Naufal_Favian
# Humaira_Favian
# Dengan parameter end

# %%
nama_siswa_1= "Naufal"
nama_siswa_2= "Favian"
nama_siswa_3= "Humaira"
nama_siswa_4= "Favian"

print(nama_siswa_1, nama_siswa_2, nama_siswa_3, nama_siswa_4, sep="~")
# Out:
# Naufal~Favian~Humaira~Favian

# %%
nama_siswa_1= "Naufal"
nama_siswa_2= "Favian"
nama_siswa_3= "Humaira"
nama_siswa_4= "Favian"

print(nama_siswa_1, end="~")
print(nama_siswa_2 )
print(nama_siswa_3, end="~")
print(nama_siswa_4)
# Out:
# Naufal~Favian
# Humaira~Favian

# %% [markdown]
# #Aritmatika

# %%
print("5000*3")
# Out:
# 5000*3

# %%
#operator tanpa disimpan dalam variabel
print(5000*3)
# Out:
# 15000

# %%
#simpan operasi ke dalam variabel
harga_kojek = 6000
banyak_porsi = 3

print(harga_kojek*banyak_porsi)
# Out:
# 18000

# %%
#simpan hasil operasi kedalam variabel
harga_total_kojek = 3000*3

print(harga_total_kojek)
# Out:
# 9000

# %%
#simpan nilai operand dan hasil operasi kedalam variabel
harga_cilok = 10000
jumlah_porsi_cilok = 5
harga_total_cilok = harga_cilok*jumlah_porsi_cilok

print(harga_total_cilok)
# Out:
# 50000

# %%
uang_yang_diterima = 10000
uang_kembalian = uang_yang_diterima = harga_total_cilok

print(uang_kembalian)
# Out:
# 50000

# %%
# hitung langsung di print ()
print(24*3)
# Out:
# 72

# %%
#simpan hasil perkalian ke variabel, lalu print
total_jumlah_botol = 24*3

print(total_jumlah_botol)
# Out:
# 72

# %%
#simpan angka ke variabel lalu tampilkan perkalian langsung diprint ()
banyak_botol_per_kerdus = 24
jumlah_kerdus = 3

print(banyak_botol_per_kerdus * jumlah_kerdus)
# Out:
# 72

# %%
#simpan angka ke variabel, simpan hasil perkalian ke variabel lain, lalu print
banyak_botol_per_kerdu = 24
jumlah_kardus = 3
total_jumlah_botol = banyak_botol_per_kerdus * jumlah_kerdus

print(total_jumlah_botol)
# Out:
# 72

# %% [markdown]
# #Tipe Variabel

# %%
usia = 65

type(usia)
# Out:
# int

# %%
berat_telur = 2.5

type(berat_telur)
# Out:
# float

# %%
nama = "firda"

type(nama)
# Out:
# str

# %%
remidi = False

type(remidi)
# Out:
# bool

# %%
remidi = True

type(remidi)
# Out:
# bool

# %%
koordinat_bintang = -1.5

type(koordinat_bintang)
# Out:
# float

# %%
koordinat_titik = -8

type(koordinat_titik)
# Out:
# int

# %% [markdown]
# #Input

# %%
panjang = 10
lebar = 5

luas = panjang*lebar

print(luas)
# Out:
# 50

# %%
input()
# Out:
# 10
# '10'

# %%
panjang = input()
# Out:
# 10

# %%
print(panjang)
# Out:
# 10

# %%
lebar = input()
# Out:
# 5

# %%
print(lebar)
# Out:
# 5

# %%
luas = panjang*lebar

print(luas)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-508063834.py in <cell line: 0>()
# ----> 1 luas = panjang*lebar
#       2
#       3 print(luas)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
type(panjang)
# Out:
# str

# %%
type(lebar)
# Out:
# str

# %%
panjang = int(panjang)

# %%
lebar = int(lebar)

# %%
type(panjang)
# Out:
# int

# %%
panjang_1 = int(input("masukan panjang persegi: "))
# Out:
# masukan panjang persegi: 10

# %%
panjang_2 = int(input("masukan panjang persegi: "))
lebar_2 = int(input("masukan lebar persegi: "))

luas_2 = panjang_2*lebar_2

print(f" Luas persegi panjang adalah {luas_2} cm^2")
# Out:
# masukan panjang persegi: 4
# masukan lebar persegi: 10
#  Luas persegi panjang adalah 40 cm^2

# %%
panjang = float(input("masukan panjang (cm): "))
lebar = float(input("masukan lebar (cm): "))
tinggi = float(input("masukan tinggi (cm): "))

volume = panjang*lebar*tinggi

print(f"volume balok adalah: {volume} cm³")
# Out:
# masukan panjang (cm): 10
# masukan lebar (cm): 5
# masukan tinggi (cm): 4
# volume balok adalah: 200.0 cm³
